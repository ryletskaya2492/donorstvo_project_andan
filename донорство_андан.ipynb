# %%
import pandas as pd
# просто проверяю, что все правильно считывается, вывожу первые 5 строк через head ()
df = pd.read_csv("донорство_резы.csv", encoding='utf-8', sep=',', skipinitialspace=True)
df = df.dropna(axis=1, how='all')
df.head()
# Out:
#   Пол  Возраст 1. Какие факторы мотивируют вас сдавать кровь?  \
# 0   Ж       19    Желание помочь другим, Признание в обществе
# 1   Ж       25    Желание помочь другим, Признание в обществе
# 2   Ж       21    Желание помочь другим, Признание в обществе
# 3   Ж       18        Благодарность от медицинских учреждений
# 4   Ж       20             Чувство социальной ответственности
#
#   2. Что для вас наиболее важно в процессе донорства?  \
# 0  Удобное местоположение пункта сдачи крови, Мин...
# 1     Профессионализм и доброжелательность персонала
# 2  Удобное местоположение пункта сдачи крови, Пре...
# 3  Быстрое и комфортное оформление, Чистота и удо...
# 4  Профессионализм и доброжелательность персонала...
#
#   3. Какие преимущества вы бы хотели получать как донор?  \
# 0  Бесплатные медицинские обследования, Награды з...
# 1  Скидки и акции от партнеров, Приоритетная запи...
# 2  Мотивационные программы, Бесплатные медицински...
# 3  Бесплатные медицинские обследования, Специальн...
# 4  Мотивационные программы, Бесплатные медицински...
#
#   4. Есть ли у вас какие-либо опасения или страхи, связанные с процессом сдачи крови?  \
# 0  Боязнь боли, Страх перед возможными побочными ...
# 1  Опасения по поводу безопасности, Страх перед в...
# 2                      что кровь действительно нужна
# 3  Страх перед долгими ожиданиями, Опасения по по...
# 4  Боязнь боли, Страх перед возможными побочными ...
#
#   5. Используете ли вы когда-либо приложения для доноров?  \
# 0            Не знаю о таких приложениях, Да, иногда
# 1                                         Да, иногда
# 2            Не знаю о таких приложениях, Да, иногда
# 3                            Нет, но планирую начать
# 4                  Нет, не вижу в этом необходимости
#
#   6. Какие функции мобильного приложения или веб-сайта для доноров вы бы хотели использовать?  \
# 0  Запись на сдачу крови, Уведомления о потребнос...
# 1           Личное портфолио, Отслеживание прогресса
# 2  Напоминания о следующей сдаче, Календарь донор...
# 3  Информация о пунктах сдачи крови поблизости, П...
# 4  Истории успешных случаев, Возможность общаться...
#
#   7. Какой информацией вы бы хотели быть обеспечены перед сдачей крови?
# 0  Информация о процессе сдачи, Рекомендации по п...
# 1  Пояснения о том, как моя кровь поможет пациент...
# 2  Статистика о дефиците групп крови, Детали о по...
# 3  Рекомендации по восстановлению после сдачи, Ис...
# 4               Контактные данные для обратной связи

# %%
import matplotlib.pyplot as plt
df['Пол'].value_counts().plot(kind='bar')
plt.title('Распределение по полу')
plt.xlabel('Пол')
plt.ylabel('Количество')
plt.show()

gender_counts = df['Пол'].value_counts()
print("Женщины:", gender_counts.get('Ж', 0))
print("Мужчины:", gender_counts.get('М', 0))
# Out:
# Женщины: 58
# Мужчины: 22

# %%
import pandas as pd
import matplotlib.pyplot as plt

# описательнеы статистики по базе
print("Описательная статистика:")
print(df['Возраст'].describe())
print("\nМедиана:")
print(df['Возраст'].median())
print("\nМинимум:", df['Возраст'].min())
print("Максимум:", df['Возраст'].max())
print("\nРаспределение возраста:")
print(df['Возраст'].value_counts().sort_index())

# группировка (чтобы не было много разрозненных точек)
bins = [18, 20, 23, 26, 30, 40]
labels = ['18–20', '21–23', '24–26', '27–30', '31–40']

df['Возраст_группа'] = pd.cut(df['Возраст'], bins=bins, labels=labels)

print("\nВозрастные группы:")
print(df['Возраст_группа'].value_counts().sort_index())
print("\nВозрастные группы (%):")
print((df['Возраст_группа'].value_counts(normalize=True).sort_index() * 100).round(1))

# табличка
age_table = df['Возраст_группа'].value_counts().sort_index().reset_index()
age_table.columns = ['Возрастная группа', 'Количество']

print("\nТаблица:")
print(age_table)

# график возраста
plt.figure()
df['Возраст'].hist()
plt.title('Распределение возраста')
plt.xlabel('Возраст')
plt.ylabel('Количество')
plt.show()
# Out:
# Описательная статистика:
# count    80.000000
# mean     21.600000
# std       2.281461
# min      18.000000
# 25%      20.000000
# 50%      21.000000
# 75%      24.000000
# max      25.000000
# Name: Возраст, dtype: float64
#
# Медиана:
# 21.0
#
# Минимум: 18
# Максимум: 25
#
# Распределение возраста:
# Возраст
# 18     7
# 19    12
# 20     9
# 21    14
# 22     8
# 23     7
# 24    12
# 25    11
# Name: count, dtype: int64
#
# Возрастные группы:
# Возраст_группа
# 18–20    21
# 21–23    29
# 24–26    23
# 27–30     0
# 31–40     0
# Name: count, dtype: int64
#
# Возрастные группы (%):
# Возраст_группа
# 18–20    28.8
# 21–23    39.7
# 24–26    31.5
# 27–30     0.0
# 31–40     0.0
# Name: proportion, dtype: float64
#
# Таблица:
#   Возрастная группа  Количество
# 0             18–20          21
# 1             21–23          29
# 2             24–26          23
# 3             27–30           0
# 4             31–40           0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# список вариантов, иначе питон считает некоторые варинты как два (из за запятой, поэтому я задаю список допустимых вариантов

options_q1 = [
    'Желание помочь другим',
    'Моральное удовлетворение',
    'Признание в обществе',
    'Личный опыт',
    'Благодарность от медицинских учреждений',
    'Получение наград или привилегий',
    'Чувство социальной ответственности',
    'Социальная ответственность'
]

options_q2 = [
    'Удобное местоположение пункта сдачи крови',
    'Быстрое и комфортное оформление',
    'Профессионализм и доброжелательность персонала',
    'Чистота и удобство помещения',
    'Процесс сдачи крови без боли',
    'Минимальное время ожидания',
    'Доступность информации о процессе сдачи крови',
    'Возможность записи на сдачу крови заранее',
    'Информация о том, как моя кровь поможет людям',
    'Преимущества для регулярных доноров'
]

options_q3 = [
    'Бесплатные медицинские обследования',
    'Награды за количество сдач',
    'Скидки и акции от партнеров',
    'Приоритетная запись в пунктах сдачи крови',
    'Приоритетная запись',
    'Участие в закрытых мероприятиях',
    'Мотивационные программы',
    'Участие в просветительских акциях',
    'Специальные медали, сертификаты или значки для донора',
    'Специальные медали'
]

options_q4 = [
    'Страх уколов',
    'Боязнь боли',
    'Страх перед возможными побочными эффектами',
    'Опасения по поводу безопасности',
    'Страх, что после сдачи крови буду плохо себя чувствовать',
    'Опасения по поводу недостаточного питания',
    'Недостаток информации о процессе',
    'Неуверенность в том, что кровь действительно нужна',
    'Страх перед долгими ожиданиями'
]

options_q5 = [
    'Да, регулярно',
    'Да, иногда',
    'Нет, никогда',
    'Нет, но планирую начать',
    'Нет, не вижу в этом необходимости',
    'Не знаю о таких приложениях'
]

options_q6 = [
    'Запись на сдачу крови в удобное время',
    'Уведомления о потребности в моей группе крови',
    'Личное портфолио с данными о количестве сдач крови',
    'Отслеживание прогресса и достижений',
    'Напоминания о следующей сдаче крови',
    'Календарь донорских акций и мероприятий',
    'Информация о пунктах сдачи крови поблизости',
    'Интерактивные карты с маршрутами к пунктам сдачи',
    'Просмотр информации о том, как именно моя кровь помогла другим',
    'Истории успешных случаев и отзывы от других доноров',
    'Вопросы и ответы, которые могут помочь новичкам',
    'Возможность общаться с другими донорами'
]

options_q7 = [
    'Информация о процессе сдачи крови',
    'Рекомендации по подготовке к сдаче',
    'Пояснения о том, как моя кровь поможет пациентам',
    'Информация о безопасности сдачи крови',
    'Детали о возможных побочных эффектах и их предупреждении',
    'Расписание работы пунктов сдачи крови',
    'Статистика о дефиците групп крови и актуальности сдачи',
    'Рекомендации по восстановлению после сдачи крови',
    'Истории доноров и положительные примеры',
    'Контактные данные для обратной связи с медицинским учреждением'
]

# подсчет

def count_selected_options(column_name, options):
    counts = {option: 0 for option in options}
    
    for value in df[column_name].dropna():
        value = str(value)
        for option in options:
            if option in value:
                counts[option] += 1
                
    result = pd.DataFrame(list(counts.items()), columns=['Ответ', 'Количество'])
    result = result.sort_values(by='Количество', ascending=False)
    return result

# также названия столбцов допустимые

q1 = '1. Какие факторы мотивируют вас сдавать кровь?'
q2 = '2. Что для вас наиболее важно в процессе донорства?'
q3 = '3. Какие преимущества вы бы хотели получать как донор?'
q4 = '4. Есть ли у вас какие-либо опасения или страхи, связанные с процессом сдачи крови?'
q5 = '5. Используете ли вы когда-либо приложения для доноров?'
q6 = '6. Какие функции мобильного приложения или веб-сайта для доноров вы бы хотели использовать?'
q7 = '7. Какой информацией вы бы хотели быть обеспечены перед сдачей крови?'

# считаем

table_q1 = count_selected_options(q1, options_q1)
table_q2 = count_selected_options(q2, options_q2)
table_q3 = count_selected_options(q3, options_q3)
table_q4 = count_selected_options(q4, options_q4)
table_q5 = count_selected_options(q5, options_q5)
table_q6 = count_selected_options(q6, options_q6)
table_q7 = count_selected_options(q7, options_q7)

# вывод подсчетов

print('\nВОПРОС 1')
print(table_q1)

print('\nВОПРОС 2')
print(table_q2)

print('\nВОПРОС 3')
print(table_q3)

print('\nВОПРОС 4')
print(table_q4)

print('\nВОПРОС 5')
print(table_q5)

print('\nВОПРОС 6')
print(table_q6)

print('\nВОПРОС 7')
print(table_q7)

# функиция для показал графика

def plot_answers(table, title):
    plt.figure(figsize=(10, 6))
    plt.barh(table['Ответ'], table['Количество'])
    plt.gca().invert_yaxis()
    plt.title(title)
    plt.xlabel('Количество выборов')
    plt.ylabel('Ответ')
    plt.tight_layout()
    plt.show()

# сами графики

plot_answers(table_q1, 'Вопрос 1. Мотивация')
plot_answers(table_q2, 'Вопрос 2. Что важно в процессе донорства')
plot_answers(table_q3, 'Вопрос 3. Желаемые преимущества')
plot_answers(table_q4, 'Вопрос 4. Страхи и опасения')
plot_answers(table_q5, 'Вопрос 5. Использование приложений')
plot_answers(table_q6, 'Вопрос 6. Желаемые функции приложения')
plot_answers(table_q7, 'Вопрос 7. Нужная информация перед сдачей крови')
# Out:
# ВОПРОС 1
#                                      Ответ  Количество
# 0                    Желание помочь другим          36
# 2                     Признание в обществе          35
# 5          Получение наград или привилегий          13
# 3                              Личный опыт          12
# 6       Чувство социальной ответственности          10
# 1                 Моральное удовлетворение           9
# 7               Социальная ответственность           8
# 4  Благодарность от медицинских учреждений           4
#
# ВОПРОС 2
#                                             Ответ  Количество
# 4                    Процесс сдачи крови без боли          45
# 2  Профессионализм и доброжелательность персонала          36
# 8   Информация о том, как моя кровь поможет людям          26
# 9             Преимущества для регулярных доноров          14
# 0       Удобное местоположение пункта сдачи крови          12
# 5                      Минимальное время ожидания          11
# 1                 Быстрое и комфортное оформление           7
# 3                    Чистота и удобство помещения           7
# 7       Возможность записи на сдачу крови заранее           3
# 6   Доступность информации о процессе сдачи крови           1
#
# ВОПРОС 3
#                                                Ответ  Количество
# 0                Бесплатные медицинские обследования          37
# 6                            Мотивационные программы          33
# 9                                 Специальные медали          31
# 8  Специальные медали, сертификаты или значки для...          24
# 4                                Приоритетная запись          17
# 2                        Скидки и акции от партнеров          15
# 1                         Награды за количество сдач           7
# 3          Приоритетная запись в пунктах сдачи крови           6
# 5                    Участие в закрытых мероприятиях           6
# 7                  Участие в просветительских акциях           6
#
# ВОПРОС 4
#                                                Ответ  Количество
# 0                                       Страх уколов          40
# 2         Страх перед возможными побочными эффектами          33
# 1                                        Боязнь боли          32
# 3                    Опасения по поводу безопасности          15
# 8                     Страх перед долгими ожиданиями          12
# 5          Опасения по поводу недостаточного питания           8
# 4  Страх, что после сдачи крови буду плохо себя ч...           4
# 7  Неуверенность в том, что кровь действительно н...           3
# 6                   Недостаток информации о процессе           0
#
# ВОПРОС 5
#                                Ответ  Количество
# 5        Не знаю о таких приложениях          34
# 1                         Да, иногда          29
# 0                      Да, регулярно           7
# 3            Нет, но планирую начать           5
# 4  Нет, не вижу в этом необходимости           5
# 2                       Нет, никогда           4
#
# ВОПРОС 6
#                                                 Ответ  Количество
# 0               Запись на сдачу крови в удобное время          15
# 1       Уведомления о потребности в моей группе крови          15
# 3                 Отслеживание прогресса и достижений          15
# 5             Календарь донорских акций и мероприятий          15
# 8   Просмотр информации о том, как именно моя кров...          15
# 6         Информация о пунктах сдачи крови поблизости           8
# 11            Возможность общаться с другими донорами           6
# 2   Личное портфолио с данными о количестве сдач к...           0
# 4                 Напоминания о следующей сдаче крови           0
# 7    Интерактивные карты с маршрутами к пунктам сдачи           0
# 9   Истории успешных случаев и отзывы от других до...           0
# 10    Вопросы и ответы, которые могут помочь новичкам           0
#
# ВОПРОС 7
#                                                Ответ  Количество
# 2   Пояснения о том, как моя кровь поможет пациентам           5
# 5              Расписание работы пунктов сдачи крови           5
# 0                  Информация о процессе сдачи крови           0
# 1                 Рекомендации по подготовке к сдаче           0
# 3              Информация о безопасности сдачи крови           0
# 4  Детали о возможных побочных эффектах и их пред...           0
# 6  Статистика о дефиците групп крови и актуальнос...           0
# 7   Рекомендации по восстановлению после сдачи крови           0
# 8            Истории доноров и положительные примеры           0
# 9  Контактные данные для обратной связи с медицин...           0
